# %% [markdown]
# Question 23: CTR by Age
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/ctr-by-age?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given two tables, `search_events` and `users`, write a query to find the three age groups. Each age
# group is bucketed by decade: age `0-9` falls into group `0`, age `10-19` to group `1`, …, `90-99` to
# group `9`, with the endpoint included) with the highest clickthrough rate in 2021.
#
# If two or more groups have the same clickthrough rate, the older group should have priority.
#
# _Note: If a user that clicked the link on 1/1/2021 is 29 years old on that day and has a birthday
# tomorrow on 2/1/2021, they fall into the [20-29] category. If the same user clicked on another link
# on 2/1/2021, he turned 30 and will fall into the [30-39] category._
#
# **Example:**
#
# **Input:**
#
# `search_events` table
#
# Column | Type
# ---|---
# `search_id` | INTEGER
# `query` | VARCHAR
# `has_clicked` | BOOLEAN
# `user_id` | INTEGER
# `search_time` | DATETIME
#
# `users` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `birthdate` | DATETIME
#
# **Output:**
#
# Column | Type
# ---|---
# `age_group` | VARCHAR
# `ctr` | FLOAT

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# search_events table mock data
search_events_data = {
    'search_id': [754, 214, 125, 859, 381],
    'query': ['purpose', 'brother', 'ago', 'site', 'face'],
    'has_clicked': [True, True, True, True, True],
    'user_id': [704, 532, 132, 130, 195],
    'search_time': pd.to_datetime(['2024-08-19', '2024-06-03', '2024-05-06', '2025-08-16', '2025-03-26']),
}
search_events = pd.DataFrame(search_events_data)

# users table mock data
users_data = {
    'id': [323, 338, 617, 716, 127],
    'name': ['Amanda Davis', 'Lance Hoffman', 'Meredith Barnes', 'Donald Booth', 'Caitlin Henderson'],
    'birthdate': pd.to_datetime(['2024-09-12', '2024-07-28', '2025-09-02', '2024-05-06', '2024-11-25']),
}
users = pd.DataFrame(users_data)

def solution():
    pass
