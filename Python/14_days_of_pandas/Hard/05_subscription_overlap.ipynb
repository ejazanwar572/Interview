# %% [markdown]
# Question 34: Subscription Overlap
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/subscription-overlap?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given a table of product subscriptions with a subscription start date and end date for each user,
# write a query that returns true or false whether or not each user has a subscription date range that
# overlaps with any other completed subscription.
#
# Completed subscriptions have `end_date` recorded.
#
# **Example:**
#
# **Input:**
#
# `subscriptions` table
#
# Column | Type
# ---|---
# `user_id` | INTEGER
# `start_date` | DATETIME
# `end_date` | DATETIME
# `user_id` | `start_date` | `end_date`
# ---|---|---
# 1 | 2019-01-01 | 2019-01-31
# 2 | 2019-01-15 | 2019-01-17
# 3 | 2019-01-29 | 2019-02-04
# 4 | 2019-02-05 | 2019-02-10
#
# **Output:**
#
# `user_id` | `overlap`
# ---|---
# 1 | 1
# 2 | 1
# 3 | 1
# 4 | 0

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# subscriptions table mock data
subscriptions_data = {
    'user_id': [754, 214, 125, 859, 381],
    'start_date': pd.to_datetime(['2025-06-03', '2024-03-11', '2024-09-10', '2024-08-03', '2025-08-13']),
    'end_date': pd.to_datetime(['2025-06-30', '2025-12-05', '2024-04-25', '2024-12-26', '2024-03-14']),
    'user_id': pd.to_datetime([350, 328, 242, 854, 204]),
    '1': ['discover', 'early', 'mouth', 'play', 'agreement'],
    '2': ['option', 'decide', 'sense', 'rate', 'science'],
    '3': ['offer', 'kind', 'discussion', 'list', 'perform'],
    '4': ['fall', 'table', 'true', 'according', 'song'],
}
subscriptions = pd.DataFrame(subscriptions_data)

def solution():
    pass
