# %% [markdown]
# Question 41: Logistic Regression from Scratch
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/logistic-regression-from-scratch?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Build a logistic regression model from scratch, with the following conditions:
#
#   * Return the parameters of the regression
#   * Do not include an intercept term
#   * Use basic gradient descent (with newton’s method) as your optimization method and the log-likelihood as your loss function.
#   * Don’t include a penalty term.
#   * You may use numpy and pandas but **NOT** scikit-learn
#
# **Example:**
#
# **Input:**
#
# `step_size = 0.02`, `max_steps = 100`
#
# `data` (100 rows × 4 columns)
#
# **Var1** | **Var2** | **Var3** | **Target**
# ---|---|---|---
# 0.44 | -0.66 | 0.03 | 1
# -1.36 | -1.30 | -1.60 | 1
# -1.71 | -2.47 | -0.97 | 1
# -1.62 | 1.32 | 1.61 | 0
# -0.32 | -1.66 | 0.13 | 0
# ... | ... | ... | ...
#
# **Output:**
#
#
#
#     def logistic_regression(data,starting_point,step_size,steps) -> [0.35155765,-0.30863254,-0.13125343]

# %%
# Question 41: Logistic Regression from Scratch
# 
# Build a logistic regression model from scratch, with the following conditions:
#
# * Return the parameters of the regression
# * Do not include an intercept term
# * Use basic gradient descent (with newton’s method) as your optimization method and the
#   log-likelihood as your loss function.
# * Don’t include a penalty term.
# * You may use numpy and pandas but **NOT** scikit-learn

import pandas as pd
import numpy as np

# Mock Data
np.random.seed(42)
data = pd.DataFrame(np.random.randn(100, 3), columns=['Var1', 'Var2', 'Var3'])
data['Target'] = np.random.randint(0, 2, 100)

def logistic_regression(data, starting_point, step_size, steps):
    pass
