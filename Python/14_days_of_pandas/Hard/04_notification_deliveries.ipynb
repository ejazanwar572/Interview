# %% [markdown]
# Question 33: Notification Deliveries
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/notification-deliveries?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# We’re given two tables, a table of `notification_deliveries` and a table of `users` with `created`
# and purchase `conversion dates`. If the user hasn’t purchased then the `conversion_date` column is
# `NULL`.
#
# Write a query to get the distribution of total push notifications before a user converts.
#
# **Example:**
#
# **Input:**
#
# `notification_deliveries` table
#
# Column | Type
# ---|---
# `notification` | VARCHAR
# `user_id` | INTEGER
# `created_at` | DATETIME
#
# `users` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `created_at` | DATETIME
# `conversion_date` | DATETIME
#
# **Output:**
#
# Column | Type
# ---|---
# `total_pushes` | INTEGER
# `frequency` | INTEGER

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# notification_deliveries table mock data
notification_deliveries_data = {
    'notification': ['purpose', 'brother', 'ago', 'site', 'face'],
    'user_id': [754, 214, 125, 859, 381],
    'created_at': pd.to_datetime(['2024-08-19', '2024-06-03', '2024-05-06', '2025-08-16', '2025-03-26']),
}
notification_deliveries = pd.DataFrame(notification_deliveries_data)

# users table mock data
users_data = {
    'id': [350, 328, 242, 854, 204],
    'created_at': pd.to_datetime(['2025-04-28', '2024-03-16', '2024-04-30', '2024-08-10', '2025-05-07']),
    'conversion_date': pd.to_datetime(['2025-04-07', '2025-07-29', '2025-07-18', '2024-12-24', '2025-01-15']),
}
users = pd.DataFrame(users_data)

def solution():
    pass
