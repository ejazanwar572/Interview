# %% [markdown]
# Question 33: Notification Deliveries
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/notification-deliveries?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# We’re given two tables, a table of `notification_deliveries` and a table of `users` with `created`
# and purchase `conversion dates`. If the user hasn’t purchased then the `conversion_date` column is
# `NULL`.
#
# Write a query to get the distribution of total push notifications before a user converts.
#
# **Example:**
#
# **Input:**
#
# `notification_deliveries` table
#
# Column | Type
# ---|---
# `notification` | VARCHAR
# `user_id` | INTEGER
# `created_at` | DATETIME
#
# `users` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `created_at` | DATETIME
# `conversion_date` | DATETIME
#
# **Output:**
#
# Column | Type
# ---|---
# `total_pushes` | INTEGER
# `frequency` | INTEGER

# %%
# Question 28: Notification Deliveries
# 
# Calculate notification delivery success rates.

import pandas as pd

# Mock Data (18 notifications, 5 users, various delivery statuses)
notifications_data = {
    'id': list(range(1, 19)),
    'user_id': [1,1,1, 2,2,2,2, 3,3, 4,4,4, 5,5,5, 1,2,3],
    'notification_type': [
        'email', 'push', 'sms',          # User 1: all 3 types
        'email', 'email', 'push', 'sms',  # User 2: dupe email
        'push', 'push',                   # User 3: only push
        'email', 'sms', 'sms',            # User 4: dupe sms
        'email', 'push', 'sms',           # User 5: all types
        'email', 'push', 'sms',           # More for users 1,2,3
    ],
    'status': [
        'delivered', 'delivered', 'failed',       # User 1: 2/3 success
        'delivered', 'bounced', 'delivered', 'delivered',  # User 2: 3/4
        'failed', 'failed',                       # User 3: 0/2 all failed ❌
        'delivered', 'delivered', 'pending',       # User 4: pending edge
        'delivered', 'delivered', 'delivered',     # User 5: 3/3 perfect ✅
        'delivered', 'failed', 'delivered',        # Additional
    ],
    'created_at': pd.to_datetime([
        '2024-01-01 09:00', '2024-01-01 09:05', '2024-01-01 09:10',
        '2024-01-01 10:00', '2024-01-01 10:05', '2024-01-01 10:10', '2024-01-01 10:15',
        '2024-01-01 11:00', '2024-01-01 11:05',
        '2024-01-01 12:00', '2024-01-01 12:05', '2024-01-01 12:10',
        '2024-01-02 09:00', '2024-01-02 09:05', '2024-01-02 09:10',
        '2024-01-02 10:00', '2024-01-02 10:05', '2024-01-02 10:10',
    ])
}
notifications = pd.DataFrame(notifications_data)

def solution():
    # Write your solution here
    pass

solution()
