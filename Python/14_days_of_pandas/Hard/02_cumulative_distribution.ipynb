# %% [markdown]
# Question 31: Cumulative Distribution
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/cumulative-distribution?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given the two tables, write a SQL query that creates a cumulative distribution of the number of
# comments per user. Assume bin buckets class intervals of one.
#
# **Example:**
#
# **Input:**
#
# `users` table
#
# Columns | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `created_at` | DATETIME
# `neighborhood_id` | INTEGER
# `sex` | VARCHAR
#
# `comments` table
#
# Columns | Type
# ---|---
# `user_id` | INTEGER
# `body` | VARCHAR
# `created_at` | DATETIME
#
# **Output:**
#
# Columns | Type
# ---|---
# `frequency` | INTEGER
# `cum_total` | FLOAT

# %%
# Question 18: Cumulative Distribution
# 
# Calculate the cumulative distribution of salaries.

import pandas as pd

# Mock Data (12 employees with ties and gaps)
salaries_data = {
    'id': list(range(1, 13)),
    'name': ['Alice', 'Bob', 'Carol', 'Dave', 'Eve', 'Frank',
             'Grace', 'Hank', 'Ivy', 'Jack', 'Kate', 'Leo'],
    'salary': [
        50000,   # Lowest
        50000,   # Tied with Alice ✅ (tests tied rank handling)
        60000,
        75000,
        75000,   # Tied ✅
        80000,
        90000,
        100000,
        100000,  # Tied ✅
        100000,  # Triple tie ✅
        120000,
        150000,  # Highest
    ],
    'department': ['Eng', 'Sales', 'Eng', 'HR', 'Eng', 'Sales',
                   'HR', 'Eng', 'Sales', 'HR', 'Eng', 'Sales'],
    'created_at': pd.to_datetime([
        '2020-01-01', '2020-03-15', '2020-06-01', '2021-01-10',
        '2021-04-20', '2021-07-01', '2021-10-15', '2022-01-01',
        '2022-04-10', '2022-07-20', '2023-01-05', '2023-06-15',
    ])
}
salaries = pd.DataFrame(salaries_data)
# Tests: tied values (2-way, 3-way), even distribution, wide salary range

def solution():
    # Write your solution here
    pass

solution()
