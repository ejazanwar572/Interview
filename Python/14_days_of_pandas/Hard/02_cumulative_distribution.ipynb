# %% [markdown]
# Question 31: Cumulative Distribution
# Difficulty: Hard
# Link: https://www.interviewquery.com/questions/cumulative-distribution?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given the two tables, write a SQL query that creates a cumulative distribution of the number of
# comments per user. Assume bin buckets class intervals of one.
#
# **Example:**
#
# **Input:**
#
# `users` table
#
# Columns | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `created_at` | DATETIME
# `neighborhood_id` | INTEGER
# `sex` | VARCHAR
#
# `comments` table
#
# Columns | Type
# ---|---
# `user_id` | INTEGER
# `body` | VARCHAR
# `created_at` | DATETIME
#
# **Output:**
#
# Columns | Type
# ---|---
# `frequency` | INTEGER
# `cum_total` | FLOAT

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# users table mock data
users_data = {
    'id': [754, 214, 125, 859, 381],
    'name': ['Allison Hill', 'Noah Rhodes', 'Angie Henderson', 'Daniel Wagner', 'Cristian Santos'],
    'created_at': pd.to_datetime(['2025-03-26', '2024-08-01', '2025-04-27', '2025-10-05', '2024-02-26']),
    'neighborhood_id': [350, 328, 242, 854, 204],
    'sex': ['Other', 'Other', 'Other', 'M', 'Other'],
}
users = pd.DataFrame(users_data)

# comments table mock data
comments_data = {
    'user_id': [532, 132, 130, 195, 323],
    'body': ['sure', 'collection', 'save', 'knowledge', 'grow'],
    'created_at': pd.to_datetime(['2024-09-12', '2024-07-28', '2025-09-02', '2024-05-06', '2024-11-25']),
}
comments = pd.DataFrame(comments_data)

def solution():
    pass
