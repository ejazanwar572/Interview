# %% [markdown]
# Question 18: Comments Histogram
# Difficulty: Medium
# Link: https://www.interviewquery.com/questions/comments-histogram?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Write a SQL query to create a histogram of the number of comments per user in the month of January
# 2020.
#
# _Note: Assume bin buckets class intervals of one._
#
# _Note: Comments that were created outside of January 2020 should be counted in a “0” bucket_
#
# **Example:**
#
# **Input:**
#
# `users` table
#
# Columns | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `created_at` | DATETIME
# `neighborhood_id` | INTEGER
# `mail` | VARCHAR
#
# `comments` table
#
# Columns | Type
# ---|---
# `user_id` | INTEGER
# `body` | VARCHAR
# `created_at` | DATETIME
#
# **Output:**
#
# Column | Type
# ---|---
# `comment_count` | INTEGER
# `frequency` | INTEGER

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# users table mock data
users_data = {
    'id': [754, 214, 125, 859, 381],
    'name': ['Allison Hill', 'Noah Rhodes', 'Angie Henderson', 'Daniel Wagner', 'Cristian Santos'],
    'created_at': pd.to_datetime(['2025-03-26', '2024-08-01', '2025-04-27', '2025-10-05', '2024-02-26']),
    'neighborhood_id': [350, 328, 242, 854, 204],
    'mail': ['sure', 'collection', 'save', 'knowledge', 'grow'],
}
users = pd.DataFrame(users_data)

# comments table mock data
comments_data = {
    'user_id': [792, 858, 658, 189, 704],
    'body': ['fall', 'clearly', 'dinner', 'source', 'great'],
    'created_at': pd.to_datetime(['2024-05-06', '2024-11-25', '2024-11-10', '2024-10-30', '2024-09-02']),
}
comments = pd.DataFrame(comments_data)

def solution():
    pass
