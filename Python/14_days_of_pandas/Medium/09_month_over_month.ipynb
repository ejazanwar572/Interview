# %% [markdown]
# Question 20: Month Over Month
# Difficulty: Medium
# Link: https://www.interviewquery.com/questions/month-over-month?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given a table of `transactions` and `products`, write a function to get the `month_over_month`
# change in revenue for the year 2019. Make sure to round `month_over_month` to 2 decimal places.
#
# **Example:**
#
# **Input:**
#
# `transactions` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `user_id` | INTEGER
# `created_at` | DATETIME
# `product_id` | INTEGER
# `quantity` | INTEGER
#
# `products` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `price` | FLOAT
#
# **Output:**
#
# Column | Type
# ---|---
# `month` | INTEGER
# `month_over_month` | FLOAT

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# transactions table mock data
transactions_data = {
    'id': [754, 214, 125, 859, 381],
    'user_id': [350, 328, 242, 854, 204],
    'created_at': pd.to_datetime(['2025-06-03', '2024-03-11', '2024-09-10', '2024-08-03', '2025-08-13']),
    'product_id': [792, 858, 658, 189, 704],
    'quantity': [55, 5, 4, 12, 28],
}
transactions = pd.DataFrame(transactions_data)

# products table mock data
products_data = {
    'id': [338, 617, 716, 127, 674],
    'name': ['Stephanie Miller', 'Allen Robinson', 'Alyssa Gonzalez', 'Kimberly Robinson', 'Rhonda Smith'],
    'price': [1002.2, 3252.92, 2729.26, 1110.0, 2950.44],
}
products = pd.DataFrame(products_data)

def solution():
    pass
