# %% [markdown]
# Question 12: First Names Only
# Difficulty: Medium
# Link: https://www.interviewquery.com/questions/first-names-only?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# You’re given a dataframe containing a list of user IDs and their full names (e.g. ‘James Emerson’).
#
# Transform this dataframe into a dataframe that contains the user ids and only the first name of each
# user.
#
# **Example:**
#
# **Input:**
#
# **user_id** | **name**
# ---|---
# 1034 | James Emerson
# 9430 | Fiona Woodward
# 7281 | Alvin Gross
# 5264 | Deborah Handler
# 8995 | Leah Xue
#
# **Output:**
#
# **user_id** | **name**
# ---|---
# 1034 | James
# 9430 | Fiona
# 7281 | Alvin
# 5264 | Deborah
# 8995 | Leah

# %%
# Question 7: First Names Only
# 
# Write a function to return the first name of each employee.

import pandas as pd

# Mock Data (10 rows with name edge cases)
employees_data = {
    'id': list(range(1, 11)),
    'full_name': [
        'John Smith',           # Normal: 2 parts
        'Jane Marie Doe',       # Edge: 3 parts (middle name)
        'Alice',                # Edge: single name (no space)
        'Bob     Johnson',      # Edge: extra spaces
        'Mary-Jane Watson',     # Edge: hyphenated first name
        'Dr. James Wilson',     # Edge: prefix/title
        'Li Wei',               # Normal: Asian name
        '  Sarah Connor  ',     # Edge: leading/trailing spaces
        'Muhammad Ali Khan',    # Edge: 3 parts
        'O\'Brien Patrick',     # Edge: apostrophe in name
    ],
    'department': ['Eng', 'Eng', 'Sales', 'HR', 'Eng', 'Sales', 'HR', 'Eng', 'Sales', 'HR'],
}
employees = pd.DataFrame(employees_data)

def solution(df):
    # Write your solution here
    pass

solution(employees)
