# %% [markdown]
# Question 30: Third Unique Song
# Difficulty: Medium
# Link: https://www.interviewquery.com/questions/third-unique-song?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given a table of `song_plays` and a table of `users`, write a query to extract the earliest date
# each user played their third unique song.
#
# _Note: If a user has listened to less than three unique songs, display their name but with a`NULL`
# date and song name_
#
# **Example:**
#
# **Input:**
#
# `song_plays` table
#
# Columns | Type
# ---|---
# `user_id` | INTEGER
# `song_name` | TEXT
# `date_played` | DATETIME
#
# **users** table
#
# Columns | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
#
# **Output:**
#
# Columns | Type
# ---|---
# `name` | VARCHAR
# `date_played` | DATETIME
# `song_name` | TEXT

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# song_plays table mock data
song_plays_data = {
    'user_id': [754, 214, 125, 859, 381],
    'song_name': ['Allison Hill', 'Noah Rhodes', 'Angie Henderson', 'Daniel Wagner', 'Cristian Santos'],
    'date_played': pd.to_datetime(['2025-03-26', '2024-08-01', '2025-04-27', '2025-10-05', '2024-02-26']),
    'id': [350, 328, 242, 854, 204],
    'name': ['Melissa Peterson', 'Tyler Rogers', 'Brent Abbott', 'Renee Blair', 'Valerie Gray'],
}
song_plays = pd.DataFrame(song_plays_data)

def solution():
    pass
