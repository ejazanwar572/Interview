# %% [markdown]
# Question 5: Branch Sales Pivot
# Difficulty: Medium
# Link: https://www.interviewquery.com/questions/branch-sales-pivot?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Your company, a multinational retail corporation, has been storing sales data from various branches
# worldwide in separate tables according to the year the sales were made. The current data structure
# is proving inefficient for business analytics and the management has requested your expertise to
# streamline the data.
#
# Write a query to create a pivot table that shows total sales for each branch by year.
#
# _Note: Assume that the sales are represented by the`total_sales` column and are in USD. Each branch
# is represented by its unique `branch_id`_.
#
# ### **Example:**
#
# **Input:**
#
# For simplicity, consider two years: 2021 and 2022.
#
# `sales_2021` table
#
# Column | Type
# ---|---
# id | INTEGER
# branch_id | INTEGER
# total_sales | INTEGER
#
# `sales_2022` table
#
# Column | Type
# ---|---
# id | INTEGER
# branch_id | INTEGER
# total_sales | INTEGER
#
# **Output:**
#
# `sales_pivot` table
#
# Column | Type
# ---|---
# branch_id | INTEGER
# total_sales_2021 | INTEGER
# total_sales_2022 | INTEGER
#
# This output pivot table shows the total sales for each branch, broken down by year.

# %%
# Question 5: Branch Sales Pivot
# 
# Write a function to pivot the data so that each column represents total revenue
# for a given quarter.

import pandas as pd

# Mock Data (12 rows — multiple branches, quarters, edge cases)
sales_data = {
    'branch': [
        'Downtown', 'Downtown', 'Downtown', 'Downtown',  # All 4 quarters
        'Uptown', 'Uptown', 'Uptown',                     # Only 3 quarters (missing Q4) ❌
        'Suburb', 'Suburb',                                # Only 2 quarters
        'Downtown', 'Uptown', 'Suburb',                    # Duplicate quarters (same branch+quarter)
    ],
    'quarter': ['Q1', 'Q2', 'Q3', 'Q4', 'Q1', 'Q2', 'Q3', 'Q1', 'Q4',
                'Q1', 'Q1', 'Q1'],  # Duplicates for aggregation test
    'revenue': [50000, 60000, 55000, 70000, 45000, 48000, 52000, 30000, 35000,
                10000, 5000, 8000],   # Duplicate revenue to sum
}
sales = pd.DataFrame(sales_data)
# Edge cases: branch with missing quarters → NaN in pivot
# Edge cases: duplicate branch+quarter combos → need aggfunc='sum'

def solution(df):
    # Write your solution here
    pass

solution(sales)
