# %% [markdown]
# Question 7: Top Three Salaries
# Difficulty: Medium
# Link: https://www.interviewquery.com/questions/top-three-salaries?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Given the `employees` and `departments` table, write a query to get the top 3 highest employee
# salaries by department. If the department contains less that 3 employees, the top 2 or the top 1
# highest salaries should be listed (assume that each department has at least 1 employee).
#
# _Note: The output should include the full name of the employee in one column, the department name,
# and the salary. The output should be sorted by department name in ascending order and salary in
# descending order._
#
# **Example:**
#
# **Input:**
#
# `employees` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `first_name` | VARCHAR
# `last_name` | VARCHAR
# `salary` | INTEGER
# `department_id` | INTEGER
#
# `departments` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
#
# **Output** :
#
# Column | Type
# ---|---
# `employee_nam`e | VARCHAR
# `department_name` | VARCHAR
# `salary` | INTEGER

# %%
# Question 7: Top Three Salaries
# 
# Given the employees and departments table, write a query to get the top 3 highest
# employee
# salaries by department. If the department contains less that 3 employees, the top 2 or
# the top 1
# highest salaries should be listed (assume that each department has at least 1 employee).
#
# _Note: The output should include the full name of the employee in one column, the
# department name,
# and the salary. The output should be sorted by department name in ascending order and
# salary in
# descending order._

import pandas as pd

# Mock Data
employees_data = {
    'id': [1, 2, 3, 4, 5, 6, 7],
    'first_name': ['Joe', 'Henry', 'Sam', 'Max', 'Janet', 'Randy', 'Will'],
    'last_name': ['Smith', 'Smith', 'Smith', 'Smith', 'Smith', 'Smith', 'Smith'],
    'salary': [85000, 80000, 60000, 90000, 69000, 85000, 70000],
    'department_id': [1, 2, 2, 1, 1, 1, 1]
}
departments_data = {
    'id': [1, 2],
    'name': ['IT', 'Sales']
}
employees = pd.DataFrame(employees_data)
departments = pd.DataFrame(departments_data)
