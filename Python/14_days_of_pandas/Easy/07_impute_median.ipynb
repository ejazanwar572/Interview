# %% [markdown]
# Question 10: Impute Median
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/impute-median?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# You’re given a dataframe `df_cheeses` containing a list of the price of various cheeses from
# California. The dataframe has missing values in the price column.
#
# Write a function `cheese_median` to impute the median price of the selected California cheeses in
# place of the missing values. You may assume at least one cheese is not missing its price.
#
# **Example:**
#
# **Input:**
#
# `df_cheeses`
#
# **Name** | **Price**
# ---|---
# Bohemian Goat | 15.00
# Central Coast Bleu | None
# Cowgirl Mozzarella | 30.00
# Cypress Grove Cheddar | None
# Oakdale Colby | 45.00
#
# **Output:**
#
# **Name** | **Price**
# ---|---
# Bohemian Goat | 15.00
# Central Coast Bleu | 30.00
# Cowgirl Mozzarella | 30.00
# Cypress Grove Cheddar | 30.00
# Oakdale Colby | 45.00

# %%
# Question 10: Impute Median
# 
# Write a function cheese_median to impute the median price of the selected California
# cheeses in place of the missing values.
# You may assume at least one cheese is not missing its price.

import pandas as pd
import numpy as np

# Mock Data (10 rows with varied NaN positions)
cheeses_data = {
    'cheese_name': ['Cheddar', 'Brie', 'Gouda', 'Swiss', 'Blue',
                    'Feta', 'Parmesan', 'Mozzarella', 'Camembert', 'Provolone'],
    'price': [
        5.50,    # Known
        np.nan,  # Missing — should be imputed
        7.20,    # Known
        np.nan,  # Missing — should be imputed
        8.90,    # Known
        6.00,    # Known
        12.50,   # Known — high outlier to test median vs mean
        np.nan,  # Missing — 3rd NaN
        4.00,    # Known — lowest value
        np.nan,  # Missing — 4th NaN (tests even count of non-NaN)
    ]
    # Non-NaN values: [5.50, 7.20, 8.90, 6.00, 12.50, 4.00]
    # Sorted: [4.00, 5.50, 6.00, 7.20, 8.90, 12.50]
    # Median (even count): (6.00 + 7.20) / 2 = 6.60
}
df_cheeses = pd.DataFrame(cheeses_data)

def cheese_median(df):
    # Write your solution here (impute the nulls in 'price' with the median 'price')
    pass
    
cheese_median(df_cheeses)
