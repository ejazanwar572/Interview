# %% [markdown]
# Question 4: Manager Team Sizes
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/manager-team-sizes?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Write a query to identify the manager with the biggest team size.
#
# You may assume there is only one manager with the largest team size.
#
# **Example:**
#
# **Input:**
#
# `employees` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `manager_id` | INTEGER
#
# `managers` table
#
# Column | Type
# ---|---
# `id` | INTEGER
# `name` | VARCHAR
# `team` | VARCHAR
#
# **Output:**
#
# Column | Type
# ---|---
# `manager` | VARCHAR
# `team_size` | INTEGER

# %%
import pandas as pd

# employees table mock data
employees_data = {
    'id': [1, 2, 3, 4, 5, 6, 7],
    'name': ['Allison', 'Noah', 'Angie', 'Daniel', 'Cristian', 'Samantha', 'David'],
    'manager_id': [101, 101, 101, 102, 102, 103, 101], # Manager 101 has the biggest team (4 people)
}
employees = pd.DataFrame(employees_data)

# managers table mock data
managers_data = {
    'id': [101, 102, 103],
    'name': ['Connie Lawrence', 'Abigail Shaffer', 'Gina Moore'],
    'team': ['Engineering', 'Sales', 'HR'],
}
managers = pd.DataFrame(managers_data)

def solution():
    # Write your solution here
    pass

solution()
