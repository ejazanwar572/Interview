# %% [markdown]
# Question 9: Good Grades and Favorite Colors
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/good-grades-and-favorite-colors?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# You’re given a dataframe of students named `students_df`:
#
# `students_df` table
#
# **name** | **age** | **favorite_color** | **grade**
# ---|---|---|---
# Tim Voss | 19 | red | 91
# Nicole Johnson | 20 | yellow | 95
# Elsa Williams | 21 | green | 82
# John James | 20 | blue | 75
# Catherine Jones | 23 | green | 93
#
# Write a function named `grades_colors` to select only the rows where the student’s favorite color is
# green or red and their grade is above 90.
#
# **Example:**
#
# **Input:**
#
# `students_df`
#
# **name** | **age** | **favorite_color** | **grade**
# ---|---|---|---
# Tim Voss | 19 | red | 91
# Nicole Johnson | 20 | yellow | 95
# Elsa Williams | 21 | green | 82
# John James | 20 | blue | 75
# Catherine Jones | 23 | green | 93
#
# **Output:**
#
#
#
#     def grades_colors(students_df) ->
#
#
# **name** | **age** | **favorite_color** | **grade**
# ---|---|---|---
# Tim Voss | 19 | red | 91
# Catherine Jones | 23 | green | 93

# %%
# Question 9: Good Grades and Favorite Colors
# 
# Write a function named grades_colors to select only the rows where the student's
# favorite color is green or red and their grade is above 90.

import pandas as pd

# Mock Data (10 rows with edge cases)
students_data = {
    'name': ['Tim Voss', 'Nicole Johnson', 'Elsa Williams', 'John James',
             'Catherine Jones', 'Raj Patel', 'Lisa Chen', 'Marco Silva',
             'Ayesha Khan', 'Derek Brown'],
    'age': [19, 20, 21, 20, 23, 22, 19, 24, 21, 20],
    'favorite_color': [
        'red',     # grade 91 → ✅ included (red + above 90)
        'yellow',  # grade 95 → ❌ excluded (wrong color)
        'green',   # grade 82 → ❌ excluded (green but grade ≤ 90)
        'blue',    # grade 75 → ❌ excluded (wrong color + low grade)
        'green',   # grade 93 → ✅ included (green + above 90)
        'red',     # grade 90 → ❌ excluded (boundary: exactly 90, not ABOVE 90)
        'green',   # grade 100 → ✅ included (perfect score + green)
        'red',     # grade 45 → ❌ excluded (red but very low grade)
        'Red',     # grade 98 → ❌ or ✅ depending on case sensitivity!
        'green',   # grade 91 → ✅ included
    ],
    'grade': [91, 95, 82, 75, 93, 90, 100, 45, 98, 91]
}
students_df = pd.DataFrame(students_data)
# Expected (case-sensitive): Tim, Catherine, Lisa, Derek = 4 rows
# Edge: Raj has grade exactly 90 (boundary), Ayesha has 'Red' (case)

def grades_colors(df):
    # Write your solution here
    pass
    
grades_colors(students_df)
