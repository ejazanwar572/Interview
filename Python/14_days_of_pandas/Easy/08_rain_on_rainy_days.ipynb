# %% [markdown]
# Question 11: Rain on Rainy Days
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/rain-on-rainy-days?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# You’re given a dataframe `df_rain` containing rainfall data. The dataframe has two columns: day of
# the week and rainfall in inches.
#
# Write a function `median_rainfall` to find the median amount of rainfall **for the days on which it
# rained**.
#
# _Note: You may assume it rained on at least one of the days._
#
# **Input:**
#
# `df_rain`
#
# **Day** | **Inches**
# ---|---
# Monday | 0
# Tuesday | 1.2
# Wednesday | 0
# Thursday | 0.8
# Friday | 1
#
# **Output:**
#
#
#
#     def median_rainfall(df_rain) -> 1

# %%
# Question 11: Rain on Rainy Days
# 
# Write a function median_rainfall to find the median amount of rainfall
# **for the days on which it rained**.
# Note: You may assume it rained on at least one of the days.

import pandas as pd

# Mock Data (10 days — mix of rainy, dry, and edge cases)
rainfall = {
    'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
            'Saturday', 'Sunday', 'Monday_W2', 'Tuesday_W2', 'Wednesday_W2'],
    'Inches': [
        0,      # Dry — should be excluded ❌
        1.2,    # Rainy ✅
        0,      # Dry ❌
        0.8,    # Rainy ✅
        1.0,    # Rainy ✅
        0,      # Dry ❌
        5.5,    # Rainy — high outlier ✅
        0.1,    # Rainy — very light rain ✅
        0,      # Dry ❌
        2.3,    # Rainy ✅
    ]
    # Rainy values: [1.2, 0.8, 1.0, 5.5, 0.1, 2.3]
    # Sorted: [0.1, 0.8, 1.0, 1.2, 2.3, 5.5]
    # Median (even count): (1.0 + 1.2) / 2 = 1.1
}
df_rain = pd.DataFrame(rainfall)

def median_rainfall(df):
    # Write your solution here (remember: median of ONLY the days where Inches > 0)
    pass
    
median_rainfall(df_rain)
