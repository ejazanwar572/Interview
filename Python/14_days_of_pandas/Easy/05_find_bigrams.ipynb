# %% [markdown]
# Question 8: Find Bigrams
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/find-bigrams?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# Write a function called `find_bigrams` that takes a sentence or paragraph of strings and returns a
# list of all its bigrams in order.
#
# **Note:** A _bigram_ is a pair of consecutive words.
#
# **Example:**
#
# **Input:**
#
#
#
#     sentence =

# %%
# Question 8: Find Bigrams
# 
# Write a function called find_bigrams that takes a sentence or paragraph of strings
# and returns a list of all its bigrams in order.
# Note: A bigram is a pair of consecutive words.

# Test sentences covering different edge cases
sentence1 = "Have free hours and love children? Drive kids to school, soccer practice and other activities."
sentence2 = "Hello"                    # Edge: single word → no bigrams
sentence3 = ""                          # Edge: empty string → no bigrams
sentence4 = "the quick brown fox"       # Normal: 3 bigrams
sentence5 = "a b"                       # Edge: exactly 2 words → 1 bigram
sentence6 = "Hello   World   Test"      # Edge: multiple spaces between words

def find_bigrams(sentence):
    pass

# Expected outputs:
# find_bigrams(sentence1) → [('Have','free'), ('free','hours'), ...]
# find_bigrams(sentence2) → []
# find_bigrams(sentence3) → []
# find_bigrams(sentence4) → [('the','quick'), ('quick','brown'), ('brown','fox')]
# find_bigrams(sentence5) → [('a','b')]
