# %% [markdown]
# Question 2: Book Availability Update
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/book-availability-update?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# As a Python-proficient librarian, you’re building a system to check the availability of book copies
# more efficiently.
#
# Write a function `update_availability` to update the `copies_available` value for a specific
# `book_id` in your dataframe and return the updated dataframe.
#
# **_Note:_** _If you can’t find the`book_id`, return the original dataframe without any changes._
#
# **Example:**
#
# **Input:**
#
# **`input_df`**
#
# book_id | book_title | copies_available
# ---|---|---
# 0 | Moby Dick | 5
# 1 | 1984 | 7
# 2 | To Kill a Mockingbird | 3
# 3 | The Great Gatsby | 2
# 4 | Pride and Prejudice | 10
#
# **Output:**
#
#
#
#     update_availability(book_id=3, copies=8, df_books=input_df) ->
#
#
# book_id | book_title | copies_available
# ---|---|---
# 0 | Moby Dick | 5
# 1 | 1984 | 7
# 2 | To Kill a Mockingbird | 3
# 3 | The Great Gatsby | 8
# 4 | Pride and Prejudice | 10

# %%
import pandas as pd

# Mock Data
books_data = {
    'book_id': [101, 102, 103, 104, 105],
    'title': ['1984', 'To Kill a Mockingbird', 'The Great Gatsby', 'Pride and Prejudice', 'Moby Dick'],
    'copies_available': [3, 0, 5, 2, 1]
}
df_books = pd.DataFrame(books_data)

def update_availability(df, book_id, new_availability):
    # Write your solution here
    pass
