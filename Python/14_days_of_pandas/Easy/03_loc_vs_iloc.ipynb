# %% [markdown]
# Question 3: loc vs iloc
# Difficulty: Easy
# Link: https://www.interviewquery.com/questions/loc-vs-iloc?playlist=14-days-of-pandas
#
# Problem Description:
# ===================
# What is the difference between the `loc` and `iloc` functions in `pandas` DataFrames?

# %%
# Question 3: loc vs iloc
# 
# What is the difference between the loc and iloc functions in pandas DataFrames?

import pandas as pd

# Explain the difference between loc and iloc
